# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error
from sklearn.cross_validation import train_test_split
import matplotlib.pylab as plt
import pandas as pd, numpy as np
import xgboost as xgb

from hyperopt import hp, tpe, STATUS_OK, Trials
from hyperopt.fmin import fmin
# Out:
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_csv("train_big.csv")
test = pd.read_csv("test_big.csv")

# %%
shift = 200

ids = pd.read_csv('data/test.csv')['id']
y_train = np.log(train['loss'] + shift)
X_train = train.drop(['loss','id'], axis=1)
X_test = test.drop(['loss','id'], axis=1)

# %%
## create holdout
X_train_local, X_val, y_train_local, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
def xg_eval_mae(yhat, dtrain):
    y = dtrain.get_label()
    return 'mae', mean_absolute_error(np.exp(y)-shift,
                               np.exp(yhat)-shift)

# %%
fair_constant = 0.7
def fair_obj(preds, dtrain):
    labels = dtrain.get_label()
    x = (preds - labels)
    den = abs(x) + fair_constant
    grad = fair_constant * x / (den)
    hess = fair_constant * fair_constant / (den * den)
    return grad, hess


def objective(space):

    d_train = xgb.DMatrix(X_train_local, label=y_train_local)
    d_valid = xgb.DMatrix(X_val, label=y_val)
    watchlist = [(d_train, 'train'), (d_valid, 'eval')]

    params = {
            'seed': 0,
            'colsample_bytree': 0.8,
            'silent': 1,
            'subsample': 0.8,
            'learning_rate': 1.0,
            'objective': 'reg:linear',
            #'max_depth': space["max_depth"],
            'min_child_weight': 1,
            'booster': 'gbtree',
            'nthreads': 24}
    
    clf = xgb.train(params,
                    d_train,
                    10000,
                    watchlist,
                    early_stopping_rounds=10,
                    #obj=fair_obj,
                    feval=xg_eval_mae,
                    )

    pred = clf.predict(d_valid, ntree_limit=clf.best_ntree_limit)
    score = xg_eval_mae(pred, d_valid)
    #mae = mean_absolute_error((y_valid), (pred))

#    print "SCORE:", mae
    return{'loss':score, 'status': STATUS_OK }




def obj(space):
    print "Training with params : ", space
    d_train = xgb.DMatrix(X_train_local, label=y_train_local)
    d_valid = xgb.DMatrix(X_val, label=y_val)
    watchlist = [(d_train, 'train'), (d_valid, 'eval')]
    
    clf = xgb.train(space,
                    d_train,
                    10000,
                    watchlist,
                    early_stopping_rounds=10,
                    #obj=fair_obj,
                    feval=xg_eval_mae,
                    )

    pred = clf.predict(d_valid, ntree_limit=clf.best_ntree_limit)
    score = xg_eval_mae(pred, d_valid)
    return {'loss': score, 'status': STATUS_OK}

# %%
space ={
        'max_depth': hp.choice('max_depth', [7,8,9,10]),
        #'min_child_weight': hp.quniform ('min_child', 1, 20, 1),
        #'subsample': hp.uniform ('subsample', 0.8, 1),
        #'n_estimators' : hp.choice('n_estimators', np.arange(1000, 10000, 100, dtype=int)),
        #'learning_rate' : hp.quniform('learning_rate', 0.025, 0.5, 0.025),
        #'gamma' : hp.quniform('gamma', 0.5, 1, 0.05),
        #'colsample_bytree' : hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'seed': 0,
        'colsample_bytree': 0.8,
        #'silent': 1,
        'subsample': 0.8,
        'learning_rate': 0.7,
        'objective': 'reg:linear',
        'min_child_weight': 1,
        'booster': 'gbtree',
        'nthreads': 24
    }

# %%
#trials = Trials()
best = fmin(fn=obj,
            space=space,
            algo=tpe.suggest,
            max_evals=25, # change
            #trials=trials
           )

print(best)
# Out:
# Training with params :  {'colsample_bytree': 0.8, 'nthreads': 24, 'learning_rate': 0.7, 'min_child_weight': 1, 'subsample': 0.8, 'seed': 0, 'objective': 'reg:linear', 'max_depth': 9, 'booster': 'gbtree'}
# [0]	train-mae:2946.76	eval-mae:2951.32
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 10 rounds.
# [1]	train-mae:1878.38	eval-mae:1888.13
# [2]	train-mae:1316.37	eval-mae:1343.49
# [3]	train-mae:1195.94	eval-mae:1247.56
# [4]	train-mae:1168.5	eval-mae:1235.38
# [5]	train-mae:1146.57	eval-mae:1234.83
# [6]	train-mae:1133.87	eval-mae:1235.26
# [7]	train-mae:1118.15	eval-mae:1241.8
# [8]	train-mae:1110.41	eval-mae:1242.92
# [9]	train-mae:1104.59	eval-mae:1243.13
# [10]	train-mae:1093.88	eval-mae:1246.12
# [11]	train-mae:1088.1	eval-mae:1248.75
# [12]	train-mae:1076.82	eval-mae:1251.2
# [13]	train-mae:1069.5	eval-mae:1253.6
# [14]	train-mae:1063.21	eval-mae:1253.91
# [15]	train-mae:1057.68	eval-mae:1254.5
# Stopping. Best iteration:
# [5]	train-mae:1146.57	eval-mae:1234.83
#
# Training with params :  {'colsample_bytree': 0.8, 'nthreads': 24, 'learning_rate': 0.7, 'min_child_weight': 1, 'subsample': 0.8, 'seed': 0, 'objective': 'reg:linear', 'max_depth': 9, 'booster': 'gbtree'}
# [0]	train-mae:2946.76	eval-mae:2951.32
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 10 rounds.
# [1]	train-mae:1878.38	eval-mae:1888.13
# [2]	train-mae:1316.37	eval-mae:1343.49
# [3]	train-mae:1195.94	eval-mae:1247.56
# [4]	train-mae:1168.5	eval-mae:1235.38
# [5]	train-mae:1146.57	eval-mae:1234.83
# [6]	train-mae:1133.87	eval-mae:1235.26
# [7]	train-mae:1118.15	eval-mae:1241.8
# [8]	train-mae:1110.41	eval-mae:1242.92
# [9]	train-mae:1104.59	eval-mae:1243.13
# [10]	train-mae:1093.88	eval-mae:1246.12
# [11]	train-mae:1088.1	eval-mae:1248.75
# [12]	train-mae:1076.82	eval-mae:1251.2
# [13]	train-mae:1069.5	eval-mae:1253.6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3b28c1b02c19> in <module>()
#       3             space=space,
#       4             algo=tpe.suggest,
# ----> 5             max_evals=25, # change
#       6             #trials=trials
#       7            )
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rseed)
#     335
#     336     rval = FMinIter(algo, domain, trials, max_evals=max_evals)
# --> 337     rval.exhaust()
#     338     print 'TRIALS ARGMIN: ', trials
#     339     return trials.argmin
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/hyperopt/fmin.py in exhaust(self)
#     295     def exhaust(self):
#     296         n_done = len(self.trials)
# --> 297         self.run(self.max_evals - n_done, block_until_done=self.async)
#     298         self.trials.refresh()
#     299         return self
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     269             else:
#     270                 # -- loop over trials and do the jobs directly
# --> 271                 self.serial_evaluate()
#     272
#     273             if stopped:
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     188                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     189                 try:
# --> 190                     result = self.domain.evaluate(spec, ctrl)
#     191                 except Exception, e:
#     192                     logger.info('job exception: %s' % str(e))
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/hyperopt/fmin.py in evaluate(self, config, ctrl, attach_attachments)
#     112             pyll_rval = pyll.rec_eval(self.expr, memo=memo,
#     113                     print_node_on_error=self.rec_eval_print_node_on_error)
# --> 114             rval = self.fn(pyll_rval)
#     115
#     116         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-6-650bc82d1fe0> in obj(space)
#      63                     early_stopping_rounds=10,
#      64                     #obj=fair_obj,
# ---> 65                     feval=xg_eval_mae,
#      66                     )
#      67
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/training.pyc in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model, callbacks)
#     203                            evals=evals,
#     204                            obj=obj, feval=feval,
# --> 205                            xgb_model=xgb_model, callbacks=callbacks)
#     206
#     207
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/training.pyc in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      74         # Skip the first update if it is a recovery step.
#      75         if version % 2 == 0:
# ---> 76             bst.update(dtrain, i, obj)
#      77             bst.save_rabit_checkpoint()
#      78             version += 1
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/core.pyc in update(self, dtrain, iteration, fobj)
#     804
#     805         if fobj is None:
# --> 806             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     807         else:
#     808             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %% [markdown]
# старый добрый перебор

# %%
    # %%time
    
    seach_res = {}
    
    for g in [i/10.0 for i in range(0,5)]:
        
        space ={
        'max_depth': 6,
        #'min_child_weight': hp.quniform ('min_child', 1, 20, 1),
        #'subsample': hp.uniform ('subsample', 0.8, 1),
        #'n_estimators' : hp.choice('n_estimators', np.arange(1000, 10000, 100, dtype=int)),
        #'learning_rate' : hp.quniform('learning_rate', 0.025, 0.5, 0.025),
        #'gamma' : hp.quniform('gamma', 0.5, 1, 0.05),
        #'colsample_bytree' : hp.quniform('colsample_bytree', 0.5, 1, 0.05),
        'seed': 42,
        'colsample_bytree': 0.8,
        #'silent': 1,
        'subsample': 0.8,
        'learning_rate': 0.03,
        'objective': 'reg:linear',
        'min_child_weight': 97,
        'booster': 'gbtree',
        'nthreads': 24,
    }
    
    
        print "Training with params : ", space
        d_train = xgb.DMatrix(X_train, label=y_train)
        
        xgb.cv(space, d_train, num_boost_round=100000, nfold=3, metrics="mae", 
               feval=xg_eval_mae, early_stopping_rounds=200, verbose_eval=10, seed=42)

        
        #pred = clf.predict(d_valid, ntree_limit=clf.best_ntree_limit)
        #score = xg_eval_mae(pred, d_valid)
        
        #seach_res[mcw] = score[1]
        
        print 'min_child_weight:', mcw
        print '-----------------'
# Out:
# Training with params :  {'subsample': 0.8, 'seed': 42, 'colsample_bytree': 0.8, 'nthreads': 24, 'objective': 'reg:linear', 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 80, 'booster': 'gbtree'}
# [0]	train-mae:3233.92+7.12391	test-mae:3233.92+14.2484
# [10]	train-mae:2976.5+6.8853	test-mae:2976.55+13.8863
# [20]	train-mae:2048.82+5.69911	test-mae:2050.48+12.3487
# [30]	train-mae:1401.33+5.67503	test-mae:1410.56+10.3287
# [40]	train-mae:1215.95+4.56471	test-mae:1232.31+9.18845
# [50]	train-mae:1167.71+4.21425	test-mae:1188.64+7.89961
# [60]	train-mae:1149.59+4.02491	test-mae:1173.9+7.24461
# [70]	train-mae:1139.86+3.57061	test-mae:1166.66+7.06854
# [80]	train-mae:1133.24+3.48597	test-mae:1162.49+7.07632
learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 116, 'booster': 'gbtree'}
# [0]	train-mae:3233.92+7.12391	test-mae:3233.92+14.2484
# [10]	train-mae:2976.5+6.89271	test-mae:2976.55+13.8841
# [20]	train-mae:2048.87+5.5843	test-mae:2050.55+12.6039
# [30]	train-mae:1401.64+4.26026	test-mae:1411.09+11.6806
# [40]	train-mae:1216.58+3.1973	test-mae:1232.86+10.3523
# [50]	train-mae:1168.44+3.50314	test-mae:1188.7+8.47516
# [60]	train-mae:1150.92+3.5914	test-mae:1174.15+7.29513
# [70]	train-mae:1141.21+2.94269	test-mae:1166.71+7.02403
# [80]	train-mae:1134.35+3.22336	test-mae:1162.02+6.52417
# [90]	train-mae:1129.66+3.41697	test-mae:1159.1+6.47265
# [100]	train-mae:1125.48+3.55499	test-mae:1156.78+6.47284
# [110]	train-mae:1122.34+3.2413	test-mae:1155.12+6.77156
# [120]	train-mae:1119.3+3.37446	test-mae:1153.79+6.67585
# [130]	train-mae:1115.98+3.37707	test-mae:1152.39+6.60368
# [140]	train-mae:1113.18+3.07999	test-mae:1151.24+6.85131
# [150]	train-mae:1110.6+2.89805	test-mae:1150.3+6.9403
# [160]	train-mae:1108.09+2.72082	test-mae:1149.58+7.08014
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-61ab19503385> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'\nseach_res = {}\n\nfor mcw in range(80, 121, 1):\n    \n    space ={\n    \'max_depth\': 6,\n    #\'min_child_weight\': hp.quniform (\'min_child\', 1, 20, 1),\n    #\'subsample\': hp.uniform (\'subsample\', 0.8, 1),\n    #\'n_estimators\' : hp.choice(\'n_estimators\', np.arange(1000, 10000, 100, dtype=int)),\n    #\'learning_rate\' : hp.quniform(\'learning_rate\', 0.025, 0.5, 0.025),\n    #\'gamma\' : hp.quniform(\'gamma\', 0.5, 1, 0.05),\n    #\'colsample_bytree\' : hp.quniform(\'colsample_bytree\', 0.5, 1, 0.05),\n    \'seed\': 42,\n    \'colsample_bytree\': 0.8,\n    #\'silent\': 1,\n    \'subsample\': 0.8,\n    \'learning_rate\': 0.1,\n    \'objective\': \'reg:linear\',\n    \'min_child_weight\': mcw,\n    \'booster\': \'gbtree\',\n    \'nthreads\': 24,\n}\n\n\n    print "Training with params : ", space\n    d_train = xgb.DMatrix(X_train, label=y_train)\n    \n    xgb.cv(space, d_train, num_boost_round=100000, nfold=3, metrics="mae", \n           feval=xg_eval_mae, early_stopping_rounds=200, verbose_eval=10, seed=42)\n\n    \n    #pred = clf.predict(d_valid, ntree_limit=clf.best_ntree_limit)\n    #score = xg_eval_mae(pred, d_valid)\n    \n    #seach_res[mcw] = score[1]\n    \n    print \'min_child_weight:\', mcw\n    print \'-----------------\'')
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1174         else:
#    1175             st = clock2()
# -> 1176             exec(code, glob, local_ns)
#    1177             end = clock2()
#    1178             out = None
#
# <timed exec> in <module>()
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/training.pyc in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks)
#     399         for fold in cvfolds:
#     400             fold.update(i, obj)
# --> 401         res = aggcv([f.eval(i, feval) for f in cvfolds])
#     402
#     403         for key, mean, std in res:
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/training.pyc in eval(self, iteration, feval)
#     221     def eval(self, iteration, feval):
#     222         """"Evaluate the CVPack for one iteration."""
# --> 223         return self.bst.eval_set(self.watchlist, iteration, feval)
#     224
#     225
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/core.pyc in eval_set(self, evals, iteration, feval)
#     870             res = '[%d]' % iteration
#     871             for dmat, evname in evals:
# --> 872                 feval_ret = feval(self.predict(dmat), dmat)
#     873                 if isinstance(feval_ret, list):
#     874                     for name, val in feval_ret:
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/core.pyc in predict(self, data, output_margin, ntree_limit, pred_leaf)
#     944                                           option_mask, ntree_limit,
#     945                                           ctypes.byref(length),
# --> 946                                           ctypes.byref(preds)))
#     947         preds = ctypes2numpy(preds, length.value, np.float32)
#     948         if pred_leaf:
#
# KeyboardInterrupt:

# %% [markdown]
# mcw=1/depth=6 - [340]	train-mae:1025.23+3.91891	test-mae:1146.07+7.37434
# mcw=21/depth=6 - [460]	train-mae:1018.09+3.54485	test-mae:1144.44+6.91012
# mcw=41/depth=6 - [400]	train-mae:1043.75+3.43271	test-mae:1144.12+7.83714
# mcw=61/depth=6 - [510]	train-mae:1033.96+4.0336	test-mae:1144.49+7.20521
# mcw=81/depth=6 -
# mcw=101/depth=6 -

# %%
        space ={
            'max_depth': 6,
            'gamma' : 0,
            'colsample_bytree': 0.7,
            #'silent': 1,
            'subsample': 0.8,
            'learning_rate': 0.1,
            'objective': 'reg:linear',
            'min_child_weight': 97,
            'booster': 'gbtree',
            'nthreads': 24,
            'seed': 42
        }

    
        print "Training with params : ", space
        d_train = xgb.DMatrix(X_train, label=y_train)
        
        xgb.cv(space, d_train, num_boost_round=100000, nfold=3, metrics="mae", 
               feval=xg_eval_mae, 
               #early_stopping_rounds=100, 
               verbose_eval=10, seed=42)
# Out:
# Training with params :  {'nthreads': 24, 'learning_rate': 0.1, 'seed': 42, 'booster': 'gbtree', 'colsample_bytree': 0.7, 'min_child_weight': 97, 'subsample': 0.8, 'objective': 'reg:linear', 'max_depth': 6, 'gamma': 0, 'lambda': 1.5}
# [0]	train-mae:3233.92+7.12354	test-mae:3233.92+14.2487
# [10]	train-mae:2976.88+6.88334	test-mae:2976.9+13.8967
# [20]	train-mae:2051.11+5.60926	test-mae:2052.55+12.5829
# [30]	train-mae:1404.18+5.04386	test-mae:1412.47+10.8077
# [40]	train-mae:1219.86+5.10533	test-mae:1234.9+8.81327
# [50]	train-mae:1170.82+4.86833	test-mae:1189.76+7.20175
# [60]	train-mae:1153.08+4.84655	test-mae:1175.25+6.59042
# [70]	train-mae:1143.17+3.65502	test-mae:1167.64+6.64281
# [80]	train-mae:1136.04+3.71804	test-mae:1162.9+6.32383
# [90]	train-mae:1130.94+3.92217	test-mae:1159.8+6.24067
# [530]	train-mae:1046.25+3.50476	test-mae:1142.63+7.5961
# [540]	train-mae:1045.04+3.64002	test-mae:1142.63+7.55431
# [550]	train-mae:1043.58+3.59768	test-mae:1142.68+7.68453
# [560]	train-mae:1042.05+3.64924	test-mae:1142.69+7.67003
# [570]	train-mae:1040.66+3.87056	test-mae:1142.64+7.71048
# [580]	train-mae:1039.24+3.91353	test-mae:1142.61+7.7396
# [590]	train-mae:1038.02+4.01598	test-mae:1142.65+7.58122
# [600]	train-mae:1036.74+3.99551	test-mae:1142.69+7.60157
# [610]	train-mae:1035.51+4.24915	test-mae:1142.72+7.53678
# [620]	train-mae:1034.33+4.19905	test-mae:1142.68+7.6281
# [630]	train-mae:1033.08+4.16392	test-mae:1142.78+7.54994
# [640]	train-mae:1031.92+4.16226	test-mae:1142.86+7.58605
# [650]	train-mae:1030.65+4.06919	test-mae:1142.92+7.60984
# [660]	train-mae:1029.53+4.11932	test-mae:1143.04+7.59695
# [670]	train-mae:1028.28+3.9537	test-mae:1143.09+7.52498
# [680]	train-mae:1027.09+3.92816	test-mae:1143.13+7.6059
# [690]	train-mae:1025.87+4.17906	test-mae:1143.17+7.52757
# [700]	train-mae:1024.44+4.08963	test-mae:1143.16+7.48092
# [710]	train-mae:1023.29+4.18052	test-mae:1143.22+7.56412
# [720]	train-mae:1022.02+4.06554	test-mae:1143.36+7.54929
# [730]	train-mae:1020.78+4.13307	test-mae:1143.33+7.64273
# [740]	train-mae:1019.65+4.13333	test-mae:1143.37+7.50682
# [750]	train-mae:1018.59+4.12332	test-mae:1143.37+7.57071
# [760]	train-mae:1017.3+3.89149	test-mae:1143.45+7.68562
# [770]	train-mae:1016.36+3.9937	test-mae:1143.55+7.6392
# [780]	train-mae:1015.23+3.90021	test-mae:1143.61+7.61997
# [790]	train-mae:1013.94+3.79371	test-mae:1143.78+7.61185
# [800]	train-mae:1012.87+3.70663	test-mae:1143.92+7.58233
# [810]	train-mae:1011.57+3.60027	test-mae:1144.03+7.5937
# [820]	train-mae:1010.45+3.63944	test-mae:1144.09+7.61901
# [830]	train-mae:1009.28+3.60323	test-mae:1144.17+7.66764
# [840]	train-mae:1008.11+3.57879	test-mae:1144.26+7.75257
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-83c8abd9283b> in <module>()
#      21        feval=xg_eval_mae,
#      22        #early_stopping_rounds=100,
# ---> 23        verbose_eval=10, seed=42)
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/training.pyc in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks)
#     399         for fold in cvfolds:
#     400             fold.update(i, obj)
# --> 401         res = aggcv([f.eval(i, feval) for f in cvfolds])
#     402
#     403         for key, mean, std in res:
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/training.pyc in eval(self, iteration, feval)
#     221     def eval(self, iteration, feval):
#     222         """"Evaluate the CVPack for one iteration."""
# --> 223         return self.bst.eval_set(self.watchlist, iteration, feval)
#     224
#     225
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/core.pyc in eval_set(self, evals, iteration, feval)
#     870             res = '[%d]' % iteration
#     871             for dmat, evname in evals:
# --> 872                 feval_ret = feval(self.predict(dmat), dmat)
#     873                 if isinstance(feval_ret, list):
#     874                     for name, val in feval_ret:
#
# /home/y.romanikhin/.virtualenvs/venv/lib/python2.7/site-packages/xgboost/core.pyc in predict(self, data, output_margin, ntree_limit, pred_leaf)
#     944                                           option_mask, ntree_limit,
#     945                                           ctypes.byref(length),
# --> 946                                           ctypes.byref(preds)))
#     947         preds = ctypes2numpy(preds, length.value, np.float32)
#     948         if pred_leaf:
#
# KeyboardInterrupt:

# %% [markdown]
# lambda = 1 - [500]	train-mae:1048.78+2.86435	test-mae:1141.98+7.11705
# lambda = 0.5 - [600]	train-mae:1034.63+3.16577	test-mae:1142.85+7.39968
# lambda = 1.5 - [500]	train-mae:1049.91+3.3814	test-mae:1142.52+7.43783

# %%
colsample = 0.8 - train-mae:1048.9+3.95934	test-mae:1141.69+7.37217 
                  [490]	train-mae:1049.16+4.25344	test-mae:1142.85+6.72124

colsample = 0.7 -  [500]	train-mae:1048.78+2.86435	test-mae:1141.98+7.11705
                   [520]	train-mae:1046.2+4.21008	test-mae:1141.39+7.54647

# %% [markdown]
# subsample=0.7 - [490]	train-mae:1053.38+3.99966	test-mae:1143.67+7.41941
#
# subsample=0.75 - [420]	train-mae:1060.5+3.95251	test-mae:1143.61+6.66474
#
# subsample=0.8 - [490]	train-mae:1048.9+3.95934	test-mae:1141.69+7.37217
#
# subsample=0.85 - [690]	train-mae:1022.26+3.56749	test-mae:1143.01+7.99066
#
# subsample=0.9 - [550]	train-mae:1039.67+3.1969	test-mae:1141.81+6.42243

# %% [markdown]
# gamma = 0 - [610]	train-mae:1033.81+4.62808	test-mae:1141.75+7.59049
#
# gamma = 0.01 - [500]	train-mae:1047.51+4.35696	test-mae:1142.13+7.93495
#
# gamma = 0.1 - [490]	train-mae:1049.46+3.51804	test-mae:1142.8+7.95768
#
# gamma = 0.5 - [580]	train-mae:1037.7+4.75016	test-mae:1142.8+7.1516

# %% [markdown]
# max_depth = 3: test-mae: 1141.63+6.36582 ?? > 4k iter
# max_depth = 5: test-mae: 1138.46 - 2750
# max_depth = 6: test-mae: 1138.22 - 1660
# max_depth = 7: test-mae: 1138.32 - 1470
# max_depth = 8: test-mae: 1139.44 - ??
# max_depth = 10: test-mae:1143.01  - 600

# %%
1133.57

# %%
seach_res
# Out:
# {1: 1148.401,
#  11: 1147.177,
#  21: 1148.1711,
#  31: 1146.5968,
#  41: 1144.9031,
#  51: 1144.2423,
#  61: 1146.0494,
#  71: 1143.9772,
#  81: 1142.9365,
#  91: 1145.125}

# %%
Min_child_weight: 1 . Score: 1146.88
Min_child_weight: 11 . Score: 1148.94
Min_child_weight: 21 . Score: 1146.91
Min_child_weight: 31 . Score: 1144.52
Min_child_weight: 41 . Score: 1146.99
Min_child_weight: 51 . Score: 1145.58
Min_child_weight: 61 . Score: 1143.5
Min_child_weight: 71 . Score: 1144.04
Min_child_weight: 81 . Score: 1143.76
Min_child_weight: 91 . Score: 1143.75
# Out:
# {14: 1143.7512}

# %%
seach_res
# Out:
# {5: 1149.339,
#  6: 1147.8495,
#  7: 1146.8751,
#  8: 1150.7089,
#  9: 1150.5143,
#  10: 1155.672,
#  11: 1155.2705,
#  12: 1160.9513,
#  13: 1169.829,
#  14: 1170.7006}

# %%
def objective(space):

    clf = xgb.XGBRegressor(#n_estimators = space['n_estimators'],
                           max_depth = space['max_depth'],
                           min_child_weight = 1,
                           subsample = 0.8,
                           learning_rate = 0.5,
                           gamma = 0,
                           colsample_bytree = 0.8,
                           objective='reg:linear'
                           )

    eval_set  = [( X_train_local, y_train_local), (X_val, y_val)]

    clf.fit(X_train_local,
            y_train_local,
            eval_set=eval_set,
            eval_metric = 'rmse',
            #feval=xg_eval_mae,
            early_stopping_rounds=10)

    pred = clf.predict(X_val)
    mae = mean_absolute_error(np.exp(y_val)-shift, np.exp(pred)-shift)
#    mae = mean_absolute_error((y_valid), (pred))

#    print "SCORE:", mae
    return{'loss':mae, 'status': STATUS_OK }


space ={
        'max_depth': hp.choice('max_depth', range(7, 9)),
        #'min_child_weight': hp.quniform ('min_child', 1, 20, 1),
        #'subsample': hp.uniform ('subsample', 0.8, 1),
        #'n_estimators' : hp.choice('n_estimators', np.arange(1000, 10000, 100, dtype=int)),
        #'learning_rate' : hp.quniform('learning_rate', 0.025, 0.5, 0.025),
        #'gamma' : hp.quniform('gamma', 0.5, 1, 0.05),
        #'colsample_bytree' : hp.quniform('colsample_bytree', 0.5, 1, 0.05)
    }


trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=3, # change
            trials=trials)

print(best)
# Out:
# [0]	validation_0-rmse:3.70067	validation_1-rmse:3.70299
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.9075	validation_1-rmse:1.90984
# [2]	validation_0-rmse:1.05408	validation_1-rmse:1.05784
# [3]	validation_0-rmse:0.685975	validation_1-rmse:0.691611
# [4]	validation_0-rmse:0.552334	validation_1-rmse:0.559991
# [5]	validation_0-rmse:0.509469	validation_1-rmse:0.518744
# [6]	validation_0-rmse:0.494861	validation_1-rmse:0.505511
# [7]	validation_0-rmse:0.48855	validation_1-rmse:0.50111
# [8]	validation_0-rmse:0.485102	validation_1-rmse:0.49908
# [9]	validation_0-rmse:0.482205	validation_1-rmse:0.497057
# [10]	validation_0-rmse:0.479963	validation_1-rmse:0.495868
# [11]	validation_0-rmse:0.478588	validation_1-rmse:0.495255
# [12]	validation_0-rmse:0.477024	validation_1-rmse:0.4948
# [13]	validation_0-rmse:0.475906	validation_1-rmse:0.494369
# [14]	validation_0-rmse:0.474923	validation_1-rmse:0.493948
# [15]	validation_0-rmse:0.473616	validation_1-rmse:0.493524
# [16]	validation_0-rmse:0.472613	validation_1-rmse:0.493534
# [17]	validation_0-rmse:0.471461	validation_1-rmse:0.493364
# [18]	validation_0-rmse:0.470045	validation_1-rmse:0.493207
# [19]	validation_0-rmse:0.468834	validation_1-rmse:0.49315
# [20]	validation_0-rmse:0.467915	validation_1-rmse:0.493159
# [21]	validation_0-rmse:0.46737	validation_1-rmse:0.493093
# [22]	validation_0-rmse:0.466269	validation_1-rmse:0.492855
# [23]	validation_0-rmse:0.465072	validation_1-rmse:0.492515
# [24]	validation_0-rmse:0.464165	validation_1-rmse:0.492427
# [25]	validation_0-rmse:0.463142	validation_1-rmse:0.492345
# [26]	validation_0-rmse:0.462632	validation_1-rmse:0.492282
# [27]	validation_0-rmse:0.462206	validation_1-rmse:0.492329
# [28]	validation_0-rmse:0.461441	validation_1-rmse:0.492457
# [29]	validation_0-rmse:0.460981	validation_1-rmse:0.492433
# [30]	validation_0-rmse:0.45956	validation_1-rmse:0.49213
# [31]	validation_0-rmse:0.458766	validation_1-rmse:0.492382
# [32]	validation_0-rmse:0.457742	validation_1-rmse:0.492457
# [33]	validation_0-rmse:0.457106	validation_1-rmse:0.492536
# [34]	validation_0-rmse:0.456315	validation_1-rmse:0.49245
# [35]	validation_0-rmse:0.455783	validation_1-rmse:0.492324
# [36]	validation_0-rmse:0.454887	validation_1-rmse:0.492468
# [37]	validation_0-rmse:0.45415	validation_1-rmse:0.492729
# [38]	validation_0-rmse:0.453131	validation_1-rmse:0.492834
# [39]	validation_0-rmse:0.452425	validation_1-rmse:0.492961
# [40]	validation_0-rmse:0.451891	validation_1-rmse:0.493086
# Stopping. Best iteration:
# [30]	validation_0-rmse:0.45956	validation_1-rmse:0.49213
#
# [0]	validation_0-rmse:3.70067	validation_1-rmse:3.70299
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.9075	validation_1-rmse:1.90984
# [2]	validation_0-rmse:1.05408	validation_1-rmse:1.05784
# [3]	validation_0-rmse:0.685975	validation_1-rmse:0.691611
# [4]	validation_0-rmse:0.552334	validation_1-rmse:0.559991
# [5]	validation_0-rmse:0.509469	validation_1-rmse:0.518744
# [6]	validation_0-rmse:0.494861	validation_1-rmse:0.505511
# [7]	validation_0-rmse:0.48855	validation_1-rmse:0.50111
# [8]	validation_0-rmse:0.485102	validation_1-rmse:0.49908
# [9]	validation_0-rmse:0.482205	validation_1-rmse:0.497057
# [10]	validation_0-rmse:0.479963	validation_1-rmse:0.495868
# [11]	validation_0-rmse:0.478588	validation_1-rmse:0.495255
# [12]	validation_0-rmse:0.477024	validation_1-rmse:0.4948
# [13]	validation_0-rmse:0.475906	validation_1-rmse:0.494369
# [14]	validation_0-rmse:0.474923	validation_1-rmse:0.493948
# [15]	validation_0-rmse:0.473616	validation_1-rmse:0.493524
# [16]	validation_0-rmse:0.472613	validation_1-rmse:0.493534
# [17]	validation_0-rmse:0.471461	validation_1-rmse:0.493364
# [18]	validation_0-rmse:0.470045	validation_1-rmse:0.493207
# [19]	validation_0-rmse:0.468834	validation_1-rmse:0.49315
# [20]	validation_0-rmse:0.467915	validation_1-rmse:0.493159
# [21]	validation_0-rmse:0.46737	validation_1-rmse:0.493093
# [22]	validation_0-rmse:0.466269	validation_1-rmse:0.492855
# [23]	validation_0-rmse:0.465072	validation_1-rmse:0.492515
# [24]	validation_0-rmse:0.464165	validation_1-rmse:0.492427
# [25]	validation_0-rmse:0.463142	validation_1-rmse:0.492345
# [26]	validation_0-rmse:0.462632	validation_1-rmse:0.492282
# [27]	validation_0-rmse:0.462206	validation_1-rmse:0.492329
# [28]	validation_0-rmse:0.461441	validation_1-rmse:0.492457
# [29]	validation_0-rmse:0.460981	validation_1-rmse:0.492433
# [30]	validation_0-rmse:0.45956	validation_1-rmse:0.49213
# [31]	validation_0-rmse:0.458766	validation_1-rmse:0.492382
# [32]	validation_0-rmse:0.457742	validation_1-rmse:0.492457
# [33]	validation_0-rmse:0.457106	validation_1-rmse:0.492536
# [34]	validation_0-rmse:0.456315	validation_1-rmse:0.49245
# [35]	validation_0-rmse:0.455783	validation_1-rmse:0.492324
# [36]	validation_0-rmse:0.454887	validation_1-rmse:0.492468
# [37]	validation_0-rmse:0.45415	validation_1-rmse:0.492729
# [38]	validation_0-rmse:0.453131	validation_1-rmse:0.492834
# [39]	validation_0-rmse:0.452425	validation_1-rmse:0.492961
# [40]	validation_0-rmse:0.451891	validation_1-rmse:0.493086
# Stopping. Best iteration:
# [30]	validation_0-rmse:0.45956	validation_1-rmse:0.49213
#
# [0]	validation_0-rmse:3.70046	validation_1-rmse:3.70267
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.90691	validation_1-rmse:1.9092
# [2]	validation_0-rmse:1.05214	validation_1-rmse:1.05694
# [3]	validation_0-rmse:0.682459	validation_1-rmse:0.689523
# [4]	validation_0-rmse:0.54703	validation_1-rmse:0.55788
# [5]	validation_0-rmse:0.503708	validation_1-rmse:0.516599
# [6]	validation_0-rmse:0.488366	validation_1-rmse:0.503598
# [7]	validation_0-rmse:0.48178	validation_1-rmse:0.499763
# [8]	validation_0-rmse:0.477981	validation_1-rmse:0.497956
# [9]	validation_0-rmse:0.474487	validation_1-rmse:0.4964
# [10]	validation_0-rmse:0.472266	validation_1-rmse:0.495628
# [11]	validation_0-rmse:0.470571	validation_1-rmse:0.4953
# [12]	validation_0-rmse:0.468666	validation_1-rmse:0.495342
# [13]	validation_0-rmse:0.467313	validation_1-rmse:0.495355
# [14]	validation_0-rmse:0.465589	validation_1-rmse:0.495064
# [15]	validation_0-rmse:0.464612	validation_1-rmse:0.494823
# [16]	validation_0-rmse:0.462439	validation_1-rmse:0.494782
# [17]	validation_0-rmse:0.460984	validation_1-rmse:0.494765
# [18]	validation_0-rmse:0.45944	validation_1-rmse:0.494653
# [19]	validation_0-rmse:0.45804	validation_1-rmse:0.494552
# [20]	validation_0-rmse:0.456737	validation_1-rmse:0.494719
# [21]	validation_0-rmse:0.455744	validation_1-rmse:0.494915
# [22]	validation_0-rmse:0.4532	validation_1-rmse:0.494772
# [23]	validation_0-rmse:0.451774	validation_1-rmse:0.494767
# [24]	validation_0-rmse:0.450448	validation_1-rmse:0.494814
# [25]	validation_0-rmse:0.448464	validation_1-rmse:0.494913
# [26]	validation_0-rmse:0.446711	validation_1-rmse:0.495061
# [27]	validation_0-rmse:0.445709	validation_1-rmse:0.494953
# [28]	validation_0-rmse:0.44471	validation_1-rmse:0.495104
# [29]	validation_0-rmse:0.443289	validation_1-rmse:0.49505
# Stopping. Best iteration:
# [19]	validation_0-rmse:0.45804	validation_1-rmse:0.494552
#
# {'max_depth': 1}
